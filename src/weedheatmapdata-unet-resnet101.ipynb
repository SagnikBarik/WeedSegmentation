# %%
# !wget -O CoFly-WeedDB.zip 'https://zenodo.org/record/6697343/files/CoFly-WeedDB.zip?download=1'
# Out:
# --2025-08-11 15:15:24--  https://zenodo.org/record/6697343/files/CoFly-WeedDB.zip?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.48.194, 188.185.43.25, 188.185.45.92, ...
# Connecting to zenodo.org (zenodo.org)|188.185.48.194|:443... connected.
# HTTP request sent, awaiting response... 301 MOVED PERMANENTLY
# Location: /records/6697343/files/CoFly-WeedDB.zip [following]
# --2025-08-11 15:15:25--  https://zenodo.org/records/6697343/files/CoFly-WeedDB.zip
# Reusing existing connection to zenodo.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1198780322 (1.1G) [application/octet-stream]
# Saving to: ‘CoFly-WeedDB.zip’
#
# CoFly-WeedDB.zip    100%[===================>]   1.12G  26.0MB/s    in 87s
#
# 2025-08-11 15:16:52 (13.2 MB/s) - ‘CoFly-WeedDB.zip’ saved [1198780322/1198780322]

# %%
# %%capture
# !unzip CoFly-WeedDB.zip
# !pip install tensorflow scikit-learn scikit-image patchify albumentations segmentation-models tqdm

# %%
import numpy as np
import os
import tqdm as tqdm

from skimage.io import imread
from patchify import patchify
from skimage import io as skio
import math

import albumentations as A

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import class_weight

from tensorflow.keras.utils import normalize, to_categorical
os.environ["SM_FRAMEWORK"] = "tf.keras"
import segmentation_models as sm

# %% [markdown]
# ## Step 1: Augmentation Class
# This class, taken from augment.py, defines the image augmentation pipeline using the albumentations library. It sets up two separate transformation sequences (transform1 and transform2) that will be applied to each training image and its corresponding mask to create new, varied training samples.

# %%
class Augment:

    def __init__(self, X_train, Y_train):
        self.transform1 = A.Compose([
            A.HorizontalFlip(p=0.5),
            A.RandomRotate90(p=1.0),
            A.GridDistortion(p=1.0)
        ])
        self.transform2 = A.Compose([
            A.VerticalFlip(p=0.5),
            A.RandomRotate90(p=1.0),
            A.GridDistortion(p=1.0)
        ])
        self.X_train = X_train
        self.Y_train = Y_train

    def augment(self):
        # Create empty lists to store augmented images and masks
        augmented_images = []
        augmented_masks = []

        # Iterate over the images and masks arrays
        for i in range(len(self.X_train)):
            image = self.X_train[i]
            mask = self.Y_train[i]

            # Apply augmentation transformations to the image and mask
            augmented = self.transform1(image=image, mask=mask)
            augmented_image = augmented['image']
            augmented_mask = augmented['mask']

            # Append the augmented image and mask to the lists
            augmented_images.append(augmented_image)
            augmented_images.append(image)
            augmented_masks.append(augmented_mask)
            augmented_masks.append(mask)
            # Second agumentation
            augmented = self.transform2(image=image, mask=mask)
            augmented_image = augmented['image']
            augmented_mask = augmented['mask']

            augmented_images.append(augmented_image)
            augmented_masks.append(augmented_mask)
        # Convert the augmented image and mask lists to NumPy arrays
        augmented_images = np.array(augmented_images)
        augmented_masks = np.array(augmented_masks)

        # Print the shape of the augmented image and mask arrays
        print("Augmented Images shape:", augmented_images.shape)
        print("Augmented Masks shape:", augmented_masks.shape)
        return augmented_images, augmented_masks

# %% [markdown]
# ## Step 2: Patch Generation Class
# This class, from create_patch.py, handles the core logic of patchifying the images. It takes a list of large images and masks, pads them to be perfectly divisible by the patch size, and then uses the patchify library to extract non-overlapping patches. It includes a crucial filtering step to only keep patches that contain a meaningful amount of weed pixels, controlled by the threshold.

# %%
class Patches:

    def __init__(self, im_list, msk_list, PATCH_SIZE, threshold=0.03):
        self.im_list = im_list
        self.msk_list = msk_list
        self.PATCH_SIZE = PATCH_SIZE
        self.threshold = threshold

    def image_to_patches(self, image, b_msk=False):
        slc_size = self.PATCH_SIZE
        x = int(math.ceil(int(image.shape[0]) / (slc_size * 1.0)))
        y = int(math.ceil(int(image.shape[1]) / (slc_size * 1.0)))
        padded_shape = (x * slc_size, y * slc_size)
        if not b_msk:
            padded_rgb_image = np.zeros((padded_shape[0], padded_shape[1], 3), dtype=np.uint8)
            padded_rgb_image[:image.shape[0], :image.shape[1]] = image
            patches = patchify(padded_rgb_image, (slc_size, slc_size, 3), step=slc_size)
        elif b_msk:
            padded_rgb_image = np.zeros((padded_shape[0], padded_shape[1]), dtype=np.uint8)
            padded_rgb_image[:image.shape[0], :image.shape[1]] = image
            patches = patchify(padded_rgb_image, (slc_size, slc_size), step=slc_size)

        return patches, slc_size

    def load_image(self, path):
        """
        loads an image based on the path
        """
        rgb_image = skio.imread(path)
        return rgb_image

    def patchify_image_mask(self):
        imgs = []
        anns = []
        AREA = self.PATCH_SIZE * self.PATCH_SIZE
        f_AREA = int(self.threshold * AREA)
        print(f'Threshold: {self.threshold} * {AREA} = {f_AREA} pixels')
        print(f"Patchifying images and masks...")
        
        # Use tqdm for a progress bar
        for im_path, msk_path in tqdm.tqdm(zip(self.im_list, self.msk_list), total=len(self.im_list)):
            patches, _ = self.image_to_patches(self.load_image(im_path))
            masks, _ = self.image_to_patches(self.load_image(msk_path), b_msk=True)
            for i in range(patches.shape[0]):
                for j in range(patches.shape[1]):
                    # The original code had a shape mismatch issue here. Corrected.
                    patch = patches[i, j, 0, :, :, :]
                    mask = masks[i, j, :, :]
                    # Keep patches where the sum of mask pixels is above the threshold
                    if mask.sum() > f_AREA:
                        imgs.append(patch)
                        anns.append(mask)
        return np.array(imgs), np.array(anns)

# %% [markdown]
# ## Step 3: Main Dataset Preparation Class
# This is the orchestrator class from prepare_dataset.py. It brings everything together. The prepare_all method executes the entire pipeline from start to finish.

# %%
class Prepare_Dataset:
    def __init__(self, PATCH_SIZE, threshold=0.03, backbone='None',
                 train_split_file='./CoFly-WeedDB/train_split1.txt',
                 test_split_file='./CoFly-WeedDB/test_split1.txt', IMG_CHANNELS=3,
                 test_size=0.2, data_path='./CoFly-WeedDB'):
        self.train_split_file = train_split_file
        self.test_split_file = test_split_file
        self.PATCH_SIZE = PATCH_SIZE
        self.IMG_CHANNELS = IMG_CHANNELS
        self.test_size = test_size
        self.backbone = backbone
        self.data_path = data_path
        self.threshold = threshold

    def read_files(self, train_split_file, test_split_file):
        train_ids = []
        test_ids = []
        with open(train_split_file, 'r') as f:
            for line in f:
                train_ids.append(line.strip())

        with open(test_split_file, 'r') as f:
            for line in f:
                test_ids.append(line.strip())
        return train_ids, test_ids

    def convert_image_id_to_path(self, total_ids, path):
        img_lst = []
        msk_lst = []
        for itm in total_ids:
            image_path = os.path.join(path, 'images', itm)
            img_lst.append(image_path)
            mask_path = os.path.join(path, 'labels_1d', itm)
            msk_lst.append(mask_path)
        return img_lst, msk_lst

    def get_image_patches(self, im_list, msk_list):
        imgs, anns = Patches(im_list, msk_list, self.PATCH_SIZE, threshold=self.threshold).patchify_image_mask()
        return imgs, anns

    def label_encoder(self, train_masks):
        labellencoder = LabelEncoder()
        n, h, w = train_masks.shape
        train_masks_reshaped = train_masks.reshape(-1, 1)
        train_masks_reshaped_encoded = labellencoder.fit_transform(train_masks_reshaped.ravel())
        train_masks_encoded_original_shape = train_masks_reshaped_encoded.reshape(n, h, w)
        return train_masks_reshaped_encoded, train_masks_encoded_original_shape

    def calc_class_weights(self, train_masks_reshaped_encoded):
        unique_classes = np.unique(train_masks_reshaped_encoded)
        class_weights = class_weight.compute_class_weight(class_weight='balanced',
                                                          classes=unique_classes,
                                                          y=train_masks_reshaped_encoded)
        print("Class weights are...:", class_weights)
        return class_weights

    def train_test_split(self, train_images, mask):
        if self.backbone == 'None':
            train_images = normalize(train_images, axis=1)
        X_train, X_test, Y_train, Y_test = train_test_split(train_images, mask, test_size=self.test_size,
                                                            random_state=42)
        return X_train, X_test, Y_train, Y_test

    def augment_dataset(self, X_train, Y_train):
        X_train, Y_train = Augment(X_train, Y_train).augment()
        return X_train, Y_train

    def covert_to_categorical(self, Y_train, Y_test, n_classes):
        Y_train_cat = to_categorical(Y_train, num_classes=n_classes)
        Y_test_cat = to_categorical(Y_test, num_classes=n_classes)
        return Y_train_cat, Y_test_cat

    def prepare_all(self):
        print('Preparing Dataset...')
        train_ids, test_ids = self.read_files(train_split_file=self.train_split_file,
                                              test_split_file=self.test_split_file)
        
        total_ids = train_ids + test_ids
        print(f'Total Image IDs: {len(total_ids)}')
        
        im_path, m_path = self.convert_image_id_to_path(total_ids=total_ids, path=self.data_path)
        image_patches, mask_patches = self.get_image_patches(im_list=im_path, msk_list=m_path)

        print(f'\nInitial Shape after Patching:')
        print(f'Image Patches Shape = {image_patches.shape}')
        print(f'Mask Patches Shape  = {mask_patches.shape}')

        
        masks_reshaped_encoded, masks_encoded_original_shape = self.label_encoder(train_masks=mask_patches)

        class_weights = self.calc_class_weights(train_masks_reshaped_encoded=masks_reshaped_encoded)

        image_patches = np.squeeze(image_patches) 
        mask_patches_final = np.expand_dims(masks_encoded_original_shape, axis=-1)
        
        n_classes = len(np.unique(mask_patches_final))
        print(f'Total Classes Detected: {n_classes}')

        X_train, X_test, Y_train, Y_test = self.train_test_split(train_images=image_patches,
                                                                 mask=mask_patches_final)
        print(f'\nShape after Train-Test Split:')
        print(f'X_train shape: {X_train.shape}, Y_train shape: {Y_train.shape}')
        print(f'X_test shape:  {X_test.shape}, Y_test shape:  {Y_test.shape}')

        print('\nAugmenting Dataset...')
        X_train, Y_train = self.augment_dataset(X_train, Y_train)
        print(f'\nShape after Augmentation:')
        print(f'X_train shape: {X_train.shape}, Y_train shape: {Y_train.shape}')

        Y_train_cat, Y_test_cat = self.covert_to_categorical(Y_train=Y_train, Y_test=Y_test, n_classes=n_classes)
        
        print(f'\nFinal Categorical Shapes:')
        print(f'Y_train_cat shape: {Y_train_cat.shape}')
        print(f'Y_test_cat shape:  {Y_test_cat.shape}')

        return X_train, Y_train, Y_train_cat, X_test, Y_test, Y_test_cat, class_weights, n_classes

# %% [markdown]
# ## Step 4: Configure and Run the Pipeline
# Now we define the parameters for our dataset preparation. We are creating the D2 dataset, so we must set augment=True. We will use train_split1.txt and test_split1.txt as our data definition files.
#
# Finally, we instantiate the Prepare_Dataset class and call the prepare_all() method to run the entire process.

# %%
# --- Configuration Parameters ---
PATCH_SIZE = 256
THRESHOLD = 0.03      # Patches with less than 3% weed pixels will be discarded
BACKBONE = 'None'      # Affects normalization, 'None' will apply a standard normalization
TEST_SPLIT_SIZE = 0.2
DATA_PATH = './CoFly-WeedDB'
TRAIN_SPLIT_FILE = os.path.join(DATA_PATH, 'train_split1.txt')
TEST_SPLIT_FILE = os.path.join(DATA_PATH, 'test_split1.txt')


# --- Instantiate and Run ---
data_preparer = Prepare_Dataset(
    PATCH_SIZE=PATCH_SIZE,
    threshold=THRESHOLD,
    backbone=BACKBONE,
    test_size=TEST_SPLIT_SIZE,
    data_path=DATA_PATH,
    train_split_file=TRAIN_SPLIT_FILE,
    test_split_file=TEST_SPLIT_FILE
)

# Run the full pipeline
X_train, Y_train, Y_train_cat, X_test, Y_test, Y_test_cat, class_weights, n_classes = data_preparer.prepare_all()

print("\n\n--- DATASET PREPARATION COMPLETE ---")
print(f"Number of classes: {n_classes}")
print(f"Calculated class weights: {class_weights}")
print("\nFinal Dataset Shapes:")
print(f"X_train (images for training): \t{X_train.shape}")
print(f"Y_train (masks for training): \t{Y_train.shape}")
print(f"Y_train_cat (categorical masks): \t{Y_train_cat.shape}")
print(f"X_test (images for testing): \t\t{X_test.shape}")
print(f"Y_test (masks for testing): \t\t{Y_test.shape}")
print(f"Y_test_cat (categorical masks): \t{Y_test_cat.shape}")
# Out:
# Preparing Dataset...
# Total Image IDs: 201
# Threshold: 0.03 * 65536 = 1966 pixels
# Patchifying images and masks...
# 100%|██████████| 201/201 [00:06<00:00, 30.38it/s]
# Initial Shape after Patching:
# Image Patches Shape = (787, 256, 256, 3)
# Mask Patches Shape  = (787, 256, 256)
# Class weights are...: [ 0.30448791  9.09420397 47.43203137  1.71011964]
# Total Classes Detected: 4
#
# Shape after Train-Test Split:
# X_train shape: (629, 256, 256, 3), Y_train shape: (629, 256, 256, 1)
# X_test shape:  (158, 256, 256, 3), Y_test shape:  (158, 256, 256, 1)
#
# Augmenting Dataset...
# Augmented Images shape: (1887, 256, 256, 3)
# Augmented Masks shape: (1887, 256, 256, 1)
#
# Shape after Augmentation:
# X_train shape: (1887, 256, 256, 3), Y_train shape: (1887, 256, 256, 1)
#
# Final Categorical Shapes:
# Y_train_cat shape: (1887, 256, 256, 4)
# Y_test_cat shape:  (158, 256, 256, 4)
#
#
# --- DATASET PREPARATION COMPLETE ---
# Number of classes: 4
# Calculated class weights: [ 0.30448791  9.09420397 47.43203137  1.71011964]
#
# Final Dataset Shapes:
# X_train (images for training): 	(1887, 256, 256, 3)
# Y_train (masks for training): 	(1887, 256, 256, 1)
# Y_train_cat (categorical masks): 	(1887, 256, 256, 4)
# X_test (images for testing): 		(158, 256, 256, 3)
# Y_test (masks for testing): 		(158, 256, 256, 1)
# Y_test_cat (categorical masks): 	(158, 256, 256, 4)

# %% [markdown]
# ## Step 5: Model Architecture - U-Net with ResNet101 Backbone
# With our data fully prepared, the next step is to define the deep learning model architecture. Following the paper's methodology, we will implement a powerful and widely-used combination for semantic segmentation: U-Net with a ResNet101 backbone.

# %%
# --- Model Definition ---
# We are using a ResNet101 that has been pre-trained on ImageNet weights.
# The U-Net decoder will be built on top of this powerful encoder.
unet_resnet101_model = sm.Unet(
    backbone_name='resnet101',
    input_shape=(PATCH_SIZE, PATCH_SIZE, 3),
    classes=n_classes,
    activation='softmax',
    encoder_weights='imagenet',
    encoder_freeze=False 
)

# Print the model summary to inspect the architecture
print("--- Model Summary: U-Net with ResNet101 Backbone ---")
unet_resnet101_model.summary()
# Out:
# --- Model Summary: U-Net with ResNet100 Backbone ---
# Model: "functional_11"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ data (InputLayer)   │ (None, 256, 256,  │          0 │ -                 │
# │                     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn_data             │ (None, 256, 256,  │          9 │ data[0][0]        │
# │ (BatchNormalizatio… │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_106  │ (None, 262, 262,  │          0 │ bn_data[0][0]     │
# │ (ZeroPadding2D)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv0 (Conv2D)      │ (None, 128, 128,  │      9,408 │ zero_padding2d_1… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn0                 │ (None, 128, 128,  │        256 │ conv0[0][0]       │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ relu0 (Activation)  │ (None, 128, 128,  │          0 │ bn0[0][0]         │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_107  │ (None, 130, 130,  │          0 │ relu0[0][0]       │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pooling0            │ (None, 64, 64,    │          0 │ zero_padding2d_1… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_unit1_bn1    │ (None, 64, 64,    │        256 │ pooling0[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_unit1_relu1  │ (None, 64, 64,    │          0 │ stage1_unit1_bn1… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_unit1_conv1  │ (None, 64, 64,    │      4,096 │ stage1_unit1_rel… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_unit1_bn2    │ (None, 64, 64,    │        256 │ stage1_unit1_con… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_unit1_relu2  │ (None, 64, 64,    │          0 │ stage1_unit1_bn2… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_108  │ (None, 66, 66,    │          0 │ stage1_unit1_rel… │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_unit1_conv2  │ (None, 64, 64,    │     36,864 │ zero_padding2d_1… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_unit1_bn3    │ (None, 64, 64,    │        256 │ stage1_unit1_con… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_unit1_relu3  │ (None, 64, 64,    │          0 │ stage1_unit1_bn3… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_unit1_conv3  │ (None, 64, 64,    │     16,384 │ stage1_unit1_rel… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_unit1_sc     │ (None, 64, 64,    │     16,384 │ stage1_unit1_rel… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_98 (Add)        │ (None, 64, 64,    │          0 │ stage1_unit1_con… │
# │                     │ 256)              │            │ stage1_unit1_sc[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_unit2_bn1    │ (None, 64, 64,    │      1,024 │ add_98[0][0]      │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_unit2_relu1  │ (None, 64, 64,    │          0 │ stage1_unit2_bn1… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_unit2_conv1  │ (None, 64, 64,    │     16,384 │ stage1_unit2_rel… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_unit2_bn2    │ (None, 64, 64,    │        256 │ stage1_unit2_con… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_unit2_relu2  │ (None, 64, 64,    │          0 │ stage1_unit2_bn2… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_109  │ (None, 66, 66,    │          0 │ stage1_unit2_rel… │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_unit2_conv2  │ (None, 64, 64,    │     36,864 │ zero_padding2d_1… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_unit2_bn3    │ (None, 64, 64,    │        256 │ stage1_unit2_con… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_unit2_relu3  │ (None, 64, 64,    │          0 │ stage1_unit2_bn3… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_unit2_conv3  │ (None, 64, 64,    │     16,384 │ stage1_unit2_rel… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_99 (Add)        │ (None, 64, 64,    │          0 │ stage1_unit2_con… │
# │                     │ 256)              │            │ add_98[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_unit3_bn1    │ (None, 64, 64,    │      1,024 │ add_99[0][0]      │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_unit3_relu1  │ (None, 64, 64,    │          0 │ stage1_unit3_bn1… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_unit3_conv1  │ (None, 64, 64,    │     16,384 │ stage1_unit3_rel… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_unit3_bn2    │ (None, 64, 64,    │        256 │ stage1_unit3_con… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_unit3_relu2  │ (None, 64, 64,    │          0 │ stage1_unit3_bn2… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_110  │ (None, 66, 66,    │          0 │ stage1_unit3_rel… │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_unit3_conv2  │ (None, 64, 64,    │     36,864 │ zero_padding2d_1… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_unit3_bn3    │ (None, 64, 64,    │        256 │ stage1_unit3_con… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_unit3_relu3  │ (None, 64, 64,    │          0 │ stage1_unit3_bn3… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage1_unit3_conv3  │ (None, 64, 64,    │     16,384 │ stage1_unit3_rel… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_100 (Add)       │ (None, 64, 64,    │          0 │ stage1_unit3_con… │
# │                     │ 256)              │            │ add_99[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit1_bn1    │ (None, 64, 64,    │      1,024 │ add_100[0][0]     │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit1_relu1  │ (None, 64, 64,    │          0 │ stage2_unit1_bn1… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit1_conv1  │ (None, 64, 64,    │     32,768 │ stage2_unit1_rel… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit1_bn2    │ (None, 64, 64,    │        512 │ stage2_unit1_con… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit1_relu2  │ (None, 64, 64,    │          0 │ stage2_unit1_bn2… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_111  │ (None, 66, 66,    │          0 │ stage2_unit1_rel… │
# │ (ZeroPadding2D)     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit1_conv2  │ (None, 32, 32,    │    147,456 │ zero_padding2d_1… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit1_bn3    │ (None, 32, 32,    │        512 │ stage2_unit1_con… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit1_relu3  │ (None, 32, 32,    │          0 │ stage2_unit1_bn3… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit1_conv3  │ (None, 32, 32,    │     65,536 │ stage2_unit1_rel… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit1_sc     │ (None, 32, 32,    │    131,072 │ stage2_unit1_rel… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_101 (Add)       │ (None, 32, 32,    │          0 │ stage2_unit1_con… │
# │                     │ 512)              │            │ stage2_unit1_sc[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit2_bn1    │ (None, 32, 32,    │      2,048 │ add_101[0][0]     │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit2_relu1  │ (None, 32, 32,    │          0 │ stage2_unit2_bn1… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit2_conv1  │ (None, 32, 32,    │     65,536 │ stage2_unit2_rel… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit2_bn2    │ (None, 32, 32,    │        512 │ stage2_unit2_con… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit2_relu2  │ (None, 32, 32,    │          0 │ stage2_unit2_bn2… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_112  │ (None, 34, 34,    │          0 │ stage2_unit2_rel… │
# │ (ZeroPadding2D)     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit2_conv2  │ (None, 32, 32,    │    147,456 │ zero_padding2d_1… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit2_bn3    │ (None, 32, 32,    │        512 │ stage2_unit2_con… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit2_relu3  │ (None, 32, 32,    │          0 │ stage2_unit2_bn3… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit2_conv3  │ (None, 32, 32,    │     65,536 │ stage2_unit2_rel… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_102 (Add)       │ (None, 32, 32,    │          0 │ stage2_unit2_con… │
# │                     │ 512)              │            │ add_101[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit3_bn1    │ (None, 32, 32,    │      2,048 │ add_102[0][0]     │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit3_relu1  │ (None, 32, 32,    │          0 │ stage2_unit3_bn1… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit3_conv1  │ (None, 32, 32,    │     65,536 │ stage2_unit3_rel… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit3_bn2    │ (None, 32, 32,    │        512 │ stage2_unit3_con… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit3_relu2  │ (None, 32, 32,    │          0 │ stage2_unit3_bn2… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_113  │ (None, 34, 34,    │          0 │ stage2_unit3_rel… │
# │ (ZeroPadding2D)     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit3_conv2  │ (None, 32, 32,    │    147,456 │ zero_padding2d_1… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit3_bn3    │ (None, 32, 32,    │        512 │ stage2_unit3_con… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit3_relu3  │ (None, 32, 32,    │          0 │ stage2_unit3_bn3… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit3_conv3  │ (None, 32, 32,    │     65,536 │ stage2_unit3_rel… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_103 (Add)       │ (None, 32, 32,    │          0 │ stage2_unit3_con… │
# │                     │ 512)              │            │ add_102[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit4_bn1    │ (None, 32, 32,    │      2,048 │ add_103[0][0]     │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit4_relu1  │ (None, 32, 32,    │          0 │ stage2_unit4_bn1… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit4_conv1  │ (None, 32, 32,    │     65,536 │ stage2_unit4_rel… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit4_bn2    │ (None, 32, 32,    │        512 │ stage2_unit4_con… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit4_relu2  │ (None, 32, 32,    │          0 │ stage2_unit4_bn2… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_114  │ (None, 34, 34,    │          0 │ stage2_unit4_rel… │
# │ (ZeroPadding2D)     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit4_conv2  │ (None, 32, 32,    │    147,456 │ zero_padding2d_1… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit4_bn3    │ (None, 32, 32,    │        512 │ stage2_unit4_con… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit4_relu3  │ (None, 32, 32,    │          0 │ stage2_unit4_bn3… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_unit4_conv3  │ (None, 32, 32,    │     65,536 │ stage2_unit4_rel… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_104 (Add)       │ (None, 32, 32,    │          0 │ stage2_unit4_con… │
# │                     │ 512)              │            │ add_103[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit1_bn1    │ (None, 32, 32,    │      2,048 │ add_104[0][0]     │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit1_relu1  │ (None, 32, 32,    │          0 │ stage3_unit1_bn1… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit1_conv1  │ (None, 32, 32,    │    131,072 │ stage3_unit1_rel… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit1_bn2    │ (None, 32, 32,    │      1,024 │ stage3_unit1_con… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit1_relu2  │ (None, 32, 32,    │          0 │ stage3_unit1_bn2… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_115  │ (None, 34, 34,    │          0 │ stage3_unit1_rel… │
# │ (ZeroPadding2D)     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit1_conv2  │ (None, 16, 16,    │    589,824 │ zero_padding2d_1… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit1_bn3    │ (None, 16, 16,    │      1,024 │ stage3_unit1_con… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit1_relu3  │ (None, 16, 16,    │          0 │ stage3_unit1_bn3… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit1_conv3  │ (None, 16, 16,    │    262,144 │ stage3_unit1_rel… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit1_sc     │ (None, 16, 16,    │    524,288 │ stage3_unit1_rel… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_105 (Add)       │ (None, 16, 16,    │          0 │ stage3_unit1_con… │
# │                     │ 1024)             │            │ stage3_unit1_sc[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit2_bn1    │ (None, 16, 16,    │      4,096 │ add_105[0][0]     │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit2_relu1  │ (None, 16, 16,    │          0 │ stage3_unit2_bn1… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit2_conv1  │ (None, 16, 16,    │    262,144 │ stage3_unit2_rel… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit2_bn2    │ (None, 16, 16,    │      1,024 │ stage3_unit2_con… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit2_relu2  │ (None, 16, 16,    │          0 │ stage3_unit2_bn2… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_116  │ (None, 18, 18,    │          0 │ stage3_unit2_rel… │
# │ (ZeroPadding2D)     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit2_conv2  │ (None, 16, 16,    │    589,824 │ zero_padding2d_1… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit2_bn3    │ (None, 16, 16,    │      1,024 │ stage3_unit2_con… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit2_relu3  │ (None, 16, 16,    │          0 │ stage3_unit2_bn3… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit2_conv3  │ (None, 16, 16,    │    262,144 │ stage3_unit2_rel… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_106 (Add)       │ (None, 16, 16,    │          0 │ stage3_unit2_con… │
# │                     │ 1024)             │            │ add_105[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit3_bn1    │ (None, 16, 16,    │      4,096 │ add_106[0][0]     │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit3_relu1  │ (None, 16, 16,    │          0 │ stage3_unit3_bn1… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit3_conv1  │ (None, 16, 16,    │    262,144 │ stage3_unit3_rel… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit3_bn2    │ (None, 16, 16,    │      1,024 │ stage3_unit3_con… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit3_relu2  │ (None, 16, 16,    │          0 │ stage3_unit3_bn2… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_117  │ (None, 18, 18,    │          0 │ stage3_unit3_rel… │
# │ (ZeroPadding2D)     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit3_conv2  │ (None, 16, 16,    │    589,824 │ zero_padding2d_1… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit3_bn3    │ (None, 16, 16,    │      1,024 │ stage3_unit3_con… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit3_relu3  │ (None, 16, 16,    │          0 │ stage3_unit3_bn3… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit3_conv3  │ (None, 16, 16,    │    262,144 │ stage3_unit3_rel… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_107 (Add)       │ (None, 16, 16,    │          0 │ stage3_unit3_con… │
# │                     │ 1024)             │            │ add_106[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit4_bn1    │ (None, 16, 16,    │      4,096 │ add_107[0][0]     │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit4_relu1  │ (None, 16, 16,    │          0 │ stage3_unit4_bn1… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit4_conv1  │ (None, 16, 16,    │    262,144 │ stage3_unit4_rel… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit4_bn2    │ (None, 16, 16,    │      1,024 │ stage3_unit4_con… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit4_relu2  │ (None, 16, 16,    │          0 │ stage3_unit4_bn2… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_118  │ (None, 18, 18,    │          0 │ stage3_unit4_rel… │
# │ (ZeroPadding2D)     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit4_conv2  │ (None, 16, 16,    │    589,824 │ zero_padding2d_1… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit4_bn3    │ (None, 16, 16,    │      1,024 │ stage3_unit4_con… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit4_relu3  │ (None, 16, 16,    │          0 │ stage3_unit4_bn3… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit4_conv3  │ (None, 16, 16,    │    262,144 │ stage3_unit4_rel… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_108 (Add)       │ (None, 16, 16,    │          0 │ stage3_unit4_con… │
# │                     │ 1024)             │            │ add_107[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit5_bn1    │ (None, 16, 16,    │      4,096 │ add_108[0][0]     │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit5_relu1  │ (None, 16, 16,    │          0 │ stage3_unit5_bn1… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit5_conv1  │ (None, 16, 16,    │    262,144 │ stage3_unit5_rel… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit5_bn2    │ (None, 16, 16,    │      1,024 │ stage3_unit5_con… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit5_relu2  │ (None, 16, 16,    │          0 │ stage3_unit5_bn2… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_119  │ (None, 18, 18,    │          0 │ stage3_unit5_rel… │
# │ (ZeroPadding2D)     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit5_conv2  │ (None, 16, 16,    │    589,824 │ zero_padding2d_1… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit5_bn3    │ (None, 16, 16,    │      1,024 │ stage3_unit5_con… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit5_relu3  │ (None, 16, 16,    │          0 │ stage3_unit5_bn3… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit5_conv3  │ (None, 16, 16,    │    262,144 │ stage3_unit5_rel… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_109 (Add)       │ (None, 16, 16,    │          0 │ stage3_unit5_con… │
# │                     │ 1024)             │            │ add_108[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit6_bn1    │ (None, 16, 16,    │      4,096 │ add_109[0][0]     │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit6_relu1  │ (None, 16, 16,    │          0 │ stage3_unit6_bn1… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit6_conv1  │ (None, 16, 16,    │    262,144 │ stage3_unit6_rel… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit6_bn2    │ (None, 16, 16,    │      1,024 │ stage3_unit6_con… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit6_relu2  │ (None, 16, 16,    │          0 │ stage3_unit6_bn2… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_120  │ (None, 18, 18,    │          0 │ stage3_unit6_rel… │
# │ (ZeroPadding2D)     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit6_conv2  │ (None, 16, 16,    │    589,824 │ zero_padding2d_1… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit6_bn3    │ (None, 16, 16,    │      1,024 │ stage3_unit6_con… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit6_relu3  │ (None, 16, 16,    │          0 │ stage3_unit6_bn3… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit6_conv3  │ (None, 16, 16,    │    262,144 │ stage3_unit6_rel… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_110 (Add)       │ (None, 16, 16,    │          0 │ stage3_unit6_con… │
# │                     │ 1024)             │            │ add_109[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit7_bn1    │ (None, 16, 16,    │      4,096 │ add_110[0][0]     │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit7_relu1  │ (None, 16, 16,    │          0 │ stage3_unit7_bn1… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit7_conv1  │ (None, 16, 16,    │    262,144 │ stage3_unit7_rel… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit7_bn2    │ (None, 16, 16,    │      1,024 │ stage3_unit7_con… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit7_relu2  │ (None, 16, 16,    │          0 │ stage3_unit7_bn2… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_121  │ (None, 18, 18,    │          0 │ stage3_unit7_rel… │
# │ (ZeroPadding2D)     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit7_conv2  │ (None, 16, 16,    │    589,824 │ zero_padding2d_1… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit7_bn3    │ (None, 16, 16,    │      1,024 │ stage3_unit7_con… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit7_relu3  │ (None, 16, 16,    │          0 │ stage3_unit7_bn3… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit7_conv3  │ (None, 16, 16,    │    262,144 │ stage3_unit7_rel… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_111 (Add)       │ (None, 16, 16,    │          0 │ stage3_unit7_con… │
# │                     │ 1024)             │            │ add_110[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit8_bn1    │ (None, 16, 16,    │      4,096 │ add_111[0][0]     │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit8_relu1  │ (None, 16, 16,    │          0 │ stage3_unit8_bn1… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit8_conv1  │ (None, 16, 16,    │    262,144 │ stage3_unit8_rel… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit8_bn2    │ (None, 16, 16,    │      1,024 │ stage3_unit8_con… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit8_relu2  │ (None, 16, 16,    │          0 │ stage3_unit8_bn2… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_122  │ (None, 18, 18,    │          0 │ stage3_unit8_rel… │
# │ (ZeroPadding2D)     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit8_conv2  │ (None, 16, 16,    │    589,824 │ zero_padding2d_1… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit8_bn3    │ (None, 16, 16,    │      1,024 │ stage3_unit8_con… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit8_relu3  │ (None, 16, 16,    │          0 │ stage3_unit8_bn3… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit8_conv3  │ (None, 16, 16,    │    262,144 │ stage3_unit8_rel… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_112 (Add)       │ (None, 16, 16,    │          0 │ stage3_unit8_con… │
# │                     │ 1024)             │            │ add_111[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit9_bn1    │ (None, 16, 16,    │      4,096 │ add_112[0][0]     │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit9_relu1  │ (None, 16, 16,    │          0 │ stage3_unit9_bn1… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit9_conv1  │ (None, 16, 16,    │    262,144 │ stage3_unit9_rel… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit9_bn2    │ (None, 16, 16,    │      1,024 │ stage3_unit9_con… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit9_relu2  │ (None, 16, 16,    │          0 │ stage3_unit9_bn2… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_123  │ (None, 18, 18,    │          0 │ stage3_unit9_rel… │
# │ (ZeroPadding2D)     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit9_conv2  │ (None, 16, 16,    │    589,824 │ zero_padding2d_1… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit9_bn3    │ (None, 16, 16,    │      1,024 │ stage3_unit9_con… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit9_relu3  │ (None, 16, 16,    │          0 │ stage3_unit9_bn3… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit9_conv3  │ (None, 16, 16,    │    262,144 │ stage3_unit9_rel… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_113 (Add)       │ (None, 16, 16,    │          0 │ stage3_unit9_con… │
# │                     │ 1024)             │            │ add_112[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit10_bn1   │ (None, 16, 16,    │      4,096 │ add_113[0][0]     │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit10_relu1 │ (None, 16, 16,    │          0 │ stage3_unit10_bn… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit10_conv1 │ (None, 16, 16,    │    262,144 │ stage3_unit10_re… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit10_bn2   │ (None, 16, 16,    │      1,024 │ stage3_unit10_co… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit10_relu2 │ (None, 16, 16,    │          0 │ stage3_unit10_bn… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_124  │ (None, 18, 18,    │          0 │ stage3_unit10_re… │
# │ (ZeroPadding2D)     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit10_conv2 │ (None, 16, 16,    │    589,824 │ zero_padding2d_1… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit10_bn3   │ (None, 16, 16,    │      1,024 │ stage3_unit10_co… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit10_relu3 │ (None, 16, 16,    │          0 │ stage3_unit10_bn… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit10_conv3 │ (None, 16, 16,    │    262,144 │ stage3_unit10_re… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_114 (Add)       │ (None, 16, 16,    │          0 │ stage3_unit10_co… │
# │                     │ 1024)             │            │ add_113[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit11_bn1   │ (None, 16, 16,    │      4,096 │ add_114[0][0]     │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit11_relu1 │ (None, 16, 16,    │          0 │ stage3_unit11_bn… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit11_conv1 │ (None, 16, 16,    │    262,144 │ stage3_unit11_re… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit11_bn2   │ (None, 16, 16,    │      1,024 │ stage3_unit11_co… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit11_relu2 │ (None, 16, 16,    │          0 │ stage3_unit11_bn… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_125  │ (None, 18, 18,    │          0 │ stage3_unit11_re… │
# │ (ZeroPadding2D)     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit11_conv2 │ (None, 16, 16,    │    589,824 │ zero_padding2d_1… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit11_bn3   │ (None, 16, 16,    │      1,024 │ stage3_unit11_co… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_unit11_relu3 │ (None, 16, 16,    │          0 │ stage3_unit11_bn… │
# ...
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_unit1_conv3  │ (None, 8, 8,      │  1,048,576 │ stage4_unit1_rel… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_unit1_sc     │ (None, 8, 8,      │  2,097,152 │ stage4_unit1_rel… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_128 (Add)       │ (None, 8, 8,      │          0 │ stage4_unit1_con… │
# │                     │ 2048)             │            │ stage4_unit1_sc[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_unit2_bn1    │ (None, 8, 8,      │      8,192 │ add_128[0][0]     │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_unit2_relu1  │ (None, 8, 8,      │          0 │ stage4_unit2_bn1… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_unit2_conv1  │ (None, 8, 8, 512) │  1,048,576 │ stage4_unit2_rel… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_unit2_bn2    │ (None, 8, 8, 512) │      2,048 │ stage4_unit2_con… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_unit2_relu2  │ (None, 8, 8, 512) │          0 │ stage4_unit2_bn2… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_139  │ (None, 10, 10,    │          0 │ stage4_unit2_rel… │
# │ (ZeroPadding2D)     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_unit2_conv2  │ (None, 8, 8, 512) │  2,359,296 │ zero_padding2d_1… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_unit2_bn3    │ (None, 8, 8, 512) │      2,048 │ stage4_unit2_con… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_unit2_relu3  │ (None, 8, 8, 512) │          0 │ stage4_unit2_bn3… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_unit2_conv3  │ (None, 8, 8,      │  1,048,576 │ stage4_unit2_rel… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_129 (Add)       │ (None, 8, 8,      │          0 │ stage4_unit2_con… │
# │                     │ 2048)             │            │ add_128[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_unit3_bn1    │ (None, 8, 8,      │      8,192 │ add_129[0][0]     │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_unit3_relu1  │ (None, 8, 8,      │          0 │ stage4_unit3_bn1… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_unit3_conv1  │ (None, 8, 8, 512) │  1,048,576 │ stage4_unit3_rel… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_unit3_bn2    │ (None, 8, 8, 512) │      2,048 │ stage4_unit3_con… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_unit3_relu2  │ (None, 8, 8, 512) │          0 │ stage4_unit3_bn2… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_140  │ (None, 10, 10,    │          0 │ stage4_unit3_rel… │
# │ (ZeroPadding2D)     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_unit3_conv2  │ (None, 8, 8, 512) │  2,359,296 │ zero_padding2d_1… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_unit3_bn3    │ (None, 8, 8, 512) │      2,048 │ stage4_unit3_con… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_unit3_relu3  │ (None, 8, 8, 512) │          0 │ stage4_unit3_bn3… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_unit3_conv3  │ (None, 8, 8,      │  1,048,576 │ stage4_unit3_rel… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_130 (Add)       │ (None, 8, 8,      │          0 │ stage4_unit3_con… │
# │                     │ 2048)             │            │ add_129[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn1                 │ (None, 8, 8,      │      8,192 │ add_130[0][0]     │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ relu1 (Activation)  │ (None, 8, 8,      │          0 │ bn1[0][0]         │
# │                     │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage0_ups… │ (None, 16, 16,    │          0 │ relu1[0][0]       │
# │ (UpSampling2D)      │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage0_con… │ (None, 16, 16,    │          0 │ decoder_stage0_u… │
# │ (Concatenate)       │ 3072)             │            │ stage4_unit1_rel… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage0a_co… │ (None, 16, 16,    │  7,077,888 │ decoder_stage0_c… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage0a_bn  │ (None, 16, 16,    │      1,024 │ decoder_stage0a_… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage0a_re… │ (None, 16, 16,    │          0 │ decoder_stage0a_… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage0b_co… │ (None, 16, 16,    │    589,824 │ decoder_stage0a_… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage0b_bn  │ (None, 16, 16,    │      1,024 │ decoder_stage0b_… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage0b_re… │ (None, 16, 16,    │          0 │ decoder_stage0b_… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage1_ups… │ (None, 32, 32,    │          0 │ decoder_stage0b_… │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage1_con… │ (None, 32, 32,    │          0 │ decoder_stage1_u… │
# │ (Concatenate)       │ 768)              │            │ stage3_unit1_rel… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage1a_co… │ (None, 32, 32,    │    884,736 │ decoder_stage1_c… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage1a_bn  │ (None, 32, 32,    │        512 │ decoder_stage1a_… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage1a_re… │ (None, 32, 32,    │          0 │ decoder_stage1a_… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage1b_co… │ (None, 32, 32,    │    147,456 │ decoder_stage1a_… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage1b_bn  │ (None, 32, 32,    │        512 │ decoder_stage1b_… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage1b_re… │ (None, 32, 32,    │          0 │ decoder_stage1b_… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage2_ups… │ (None, 64, 64,    │          0 │ decoder_stage1b_… │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage2_con… │ (None, 64, 64,    │          0 │ decoder_stage2_u… │
# │ (Concatenate)       │ 384)              │            │ stage2_unit1_rel… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage2a_co… │ (None, 64, 64,    │    221,184 │ decoder_stage2_c… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage2a_bn  │ (None, 64, 64,    │        256 │ decoder_stage2a_… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage2a_re… │ (None, 64, 64,    │          0 │ decoder_stage2a_… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage2b_co… │ (None, 64, 64,    │     36,864 │ decoder_stage2a_… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage2b_bn  │ (None, 64, 64,    │        256 │ decoder_stage2b_… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage2b_re… │ (None, 64, 64,    │          0 │ decoder_stage2b_… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage3_ups… │ (None, 128, 128,  │          0 │ decoder_stage2b_… │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage3_con… │ (None, 128, 128,  │          0 │ decoder_stage3_u… │
# │ (Concatenate)       │ 128)              │            │ relu0[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage3a_co… │ (None, 128, 128,  │     36,864 │ decoder_stage3_c… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage3a_bn  │ (None, 128, 128,  │        128 │ decoder_stage3a_… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage3a_re… │ (None, 128, 128,  │          0 │ decoder_stage3a_… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage3b_co… │ (None, 128, 128,  │      9,216 │ decoder_stage3a_… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage3b_bn  │ (None, 128, 128,  │        128 │ decoder_stage3b_… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage3b_re… │ (None, 128, 128,  │          0 │ decoder_stage3b_… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage4_ups… │ (None, 256, 256,  │          0 │ decoder_stage3b_… │
# │ (UpSampling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage4a_co… │ (None, 256, 256,  │      4,608 │ decoder_stage4_u… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage4a_bn  │ (None, 256, 256,  │         64 │ decoder_stage4a_… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage4a_re… │ (None, 256, 256,  │          0 │ decoder_stage4a_… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage4b_co… │ (None, 256, 256,  │      2,304 │ decoder_stage4a_… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage4b_bn  │ (None, 256, 256,  │         64 │ decoder_stage4b_… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_stage4b_re… │ (None, 256, 256,  │          0 │ decoder_stage4b_… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ final_conv (Conv2D) │ (None, 256, 256,  │        580 │ decoder_stage4b_… │
# │                     │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ softmax             │ (None, 256, 256,  │          0 │ final_conv[0][0]  │
# │ (Activation)        │ 4)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 51,605,901 (196.86 MB)
#  Trainable params: 51,506,119 (196.48 MB)
#  Non-trainable params: 99,782 (389.77 KB)

# %%
from segmentation_models import get_preprocessing

# --- Get the preprocessing function for the ResNet101 backbone ---
# This function will normalize the images in the exact way the pre-trained model expects.
BACKBONE = 'resnet101'
preprocess_input = get_preprocessing(BACKBONE)

# --- Preprocess the training and testing data ---
# It's also good practice to ensure the data is in float32 format.
print("Preprocessing data for the efficientnetb0 model...")
X_train_preprocessed = X_train.astype('float32')
X_test_preprocessed = X_test.astype('float32')

X_train_preprocessed = preprocess_input(X_train_preprocessed)
X_test_preprocessed = preprocess_input(X_test_preprocessed)

print("Data preprocessing complete.")
print(f"Shape of preprocessed X_train: {X_train_preprocessed.shape}")
print(f"Shape of preprocessed X_test: {X_test_preprocessed.shape}")
# Out:
# Preprocessing data for the efficientnetb0 model...
# Data preprocessing complete.
# Shape of preprocessed X_train: (1887, 256, 256, 3)
# Shape of preprocessed X_test: (158, 256, 256, 3)

# %% [markdown]
# ## Step 6: Compile and Train the Model
# This is the final step where we bring everything together to train our U-Net ResNet101 model.

# %%
import tensorflow as tf
from tensorflow import keras

# --- 1. Define Loss Function, Optimizer, and Metrics ---

# The paper uses a combination of Dice Loss and Focal Loss.
# We will apply the class_weights to the Dice Loss part.
dice_loss = sm.losses.DiceLoss(class_weights=class_weights) 
focal_loss = sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1 * focal_loss)

# Define the metrics we want to track.
# IoU (Intersection over Union) is a key metric for segmentation.
metrics = [sm.metrics.IOUScore(threshold=0.5), sm.metrics.FScore(threshold=0.5)]

# Define the optimizer with a learning rate.
LR = 0.0001
optim = keras.optimizers.AdamW(LR)

# Compile the model with our defined settings.
unet_resnet101_model.compile(optimizer=optim, loss=total_loss, metrics=metrics)


# --- 2. Define Callbacks ---

# Define the path where the best model weights will be saved.
model_weights_path = 'unet_resnet101_best_model.keras'

# ModelCheckpoint saves the best model based on validation loss.
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    model_weights_path, 
    monitor='val_loss', 
    verbose=1, 
    save_best_only=True, 
    mode='min'
)

# EarlyStopping stops training if there's no improvement.
# Lowering patience slightly can make training more efficient.
early_stopping = tf.keras.callbacks.EarlyStopping(
    patience=10, 
    monitor='val_loss',
    restore_best_weights=True 
)

# NEW: ReduceLROnPlateau will reduce the learning rate if validation loss plateaus.
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', 
    factor=0.2, # Reduce LR by a factor of 5
    patience=4,  # Reduce if no improvement for 4 epochs
    verbose=1,
    min_lr=0.000001
)


callbacks_list = [checkpoint, early_stopping, reduce_lr]


# --- 3. Launch Training ---

print("\n--- Starting Model Training ---")

# These parameters are taken from the train.py script's defaults
EPOCHS = 50
BATCH_SIZE = 8
VALIDATION_SPLIT = 0.1

# The 'history' object will store the training and validation metrics for each epoch.
# IMPORTANT: Use the PREPROCESSED data here.
history = unet_resnet101_model.fit(
    X_train_preprocessed, # Use preprocessed data
    Y_train_cat,
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    validation_split=VALIDATION_SPLIT,
    callbacks=callbacks_list,
    verbose=1
)

print("\n--- Model Training Complete ---")
print(f"Best model has been saved to: {model_weights_path}")
# Out:
# --- Starting Model Training ---
# Epoch 1/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step - f1-score: 0.0885 - iou_score: 0.0578 - loss: 0.6302
# Epoch 1: val_loss improved from inf to 0.80295, saving model to unet_resnet101_best_model.keras
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 247s 545ms/step - f1-score: 0.0890 - iou_score: 0.0581 - loss: 0.6295 - val_f1-score: 0.5807 - val_iou_score: 0.5559 - val_loss: 0.8030 - learning_rate: 1.0000e-04
# Epoch 2/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - f1-score: 0.4121 - iou_score: 0.3109 - loss: -0.0025
# Epoch 2: val_loss did not improve from 0.80295
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 69s 323ms/step - f1-score: 0.4121 - iou_score: 0.3109 - loss: -0.0030 - val_f1-score: 0.2992 - val_iou_score: 0.2566 - val_loss: 0.9321 - learning_rate: 1.0000e-04
# Epoch 3/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - f1-score: 0.4395 - iou_score: 0.3413 - loss: -0.4192
# Epoch 3: val_loss did not improve from 0.80295
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 68s 320ms/step - f1-score: 0.4395 - iou_score: 0.3413 - loss: -0.4197 - val_f1-score: 0.5902 - val_iou_score: 0.5712 - val_loss: 0.9571 - learning_rate: 1.0000e-04
# Epoch 4/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - f1-score: 0.4395 - iou_score: 0.3427 - loss: -0.8373
# Epoch 4: val_loss did not improve from 0.80295
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 68s 320ms/step - f1-score: 0.4395 - iou_score: 0.3427 - loss: -0.8369 - val_f1-score: 0.5902 - val_iou_score: 0.5712 - val_loss: 0.9588 - learning_rate: 1.0000e-04
# Epoch 5/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - f1-score: 0.4666 - iou_score: 0.3708 - loss: -1.2136
# Epoch 5: val_loss did not improve from 0.80295
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 68s 321ms/step - f1-score: 0.4667 - iou_score: 0.3708 - loss: -1.2135 - val_f1-score: 0.5902 - val_iou_score: 0.5712 - val_loss: 0.9811 - learning_rate: 1.0000e-04
# Epoch 6/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - f1-score: 0.5017 - iou_score: 0.4031 - loss: -1.5882
# Epoch 6: val_loss improved from 0.80295 to 0.48553, saving model to unet_resnet101_best_model.keras
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 73s 341ms/step - f1-score: 0.5018 - iou_score: 0.4032 - loss: -1.5888 - val_f1-score: 0.6739 - val_iou_score: 0.6112 - val_loss: 0.4855 - learning_rate: 2.0000e-05
# Epoch 7/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - f1-score: 0.5153 - iou_score: 0.4200 - loss: -1.7224
# Epoch 7: val_loss improved from 0.48553 to -0.02924, saving model to unet_resnet101_best_model.keras
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 73s 341ms/step - f1-score: 0.5153 - iou_score: 0.4200 - loss: -1.7231 - val_f1-score: 0.7620 - val_iou_score: 0.6858 - val_loss: -0.0292 - learning_rate: 2.0000e-05
# Epoch 8/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - f1-score: 0.5382 - iou_score: 0.4435 - loss: -2.2210
# Epoch 8: val_loss improved from -0.02924 to -0.08161, saving model to unet_resnet101_best_model.keras
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 75s 350ms/step - f1-score: 0.5382 - iou_score: 0.4435 - loss: -2.2200 - val_f1-score: 0.6569 - val_iou_score: 0.5868 - val_loss: -0.0816 - learning_rate: 2.0000e-05
# Epoch 9/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - f1-score: 0.5458 - iou_score: 0.4540 - loss: -2.1909
# Epoch 9: val_loss improved from -0.08161 to -0.15634, saving model to unet_resnet101_best_model.keras
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 73s 341ms/step - f1-score: 0.5457 - iou_score: 0.4540 - loss: -2.1908 - val_f1-score: 0.6518 - val_iou_score: 0.5769 - val_loss: -0.1563 - learning_rate: 2.0000e-05
# Epoch 10/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - f1-score: 0.5487 - iou_score: 0.4572 - loss: -1.9462
# Epoch 10: val_loss improved from -0.15634 to -0.33209, saving model to unet_resnet101_best_model.keras
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 75s 350ms/step - f1-score: 0.5487 - iou_score: 0.4572 - loss: -1.9476 - val_f1-score: 0.7046 - val_iou_score: 0.6325 - val_loss: -0.3321 - learning_rate: 2.0000e-05
# Epoch 11/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - f1-score: 0.5686 - iou_score: 0.4776 - loss: -3.1141
# Epoch 11: val_loss did not improve from -0.33209
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 69s 321ms/step - f1-score: 0.5685 - iou_score: 0.4776 - loss: -3.1112 - val_f1-score: 0.6945 - val_iou_score: 0.6239 - val_loss: -0.3299 - learning_rate: 2.0000e-05
# Epoch 12/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - f1-score: 0.5653 - iou_score: 0.4760 - loss: -2.3656
# Epoch 12: val_loss did not improve from -0.33209
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 68s 321ms/step - f1-score: 0.5653 - iou_score: 0.4760 - loss: -2.3664 - val_f1-score: 0.6825 - val_iou_score: 0.6096 - val_loss: -0.2747 - learning_rate: 2.0000e-05
# Epoch 13/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - f1-score: 0.5805 - iou_score: 0.4896 - loss: -3.0504
# Epoch 13: val_loss did not improve from -0.33209
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 68s 321ms/step - f1-score: 0.5804 - iou_score: 0.4896 - loss: -3.0484 - val_f1-score: 0.7295 - val_iou_score: 0.6560 - val_loss: -0.3284 - learning_rate: 2.0000e-05
# Epoch 14/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - f1-score: 0.5567 - iou_score: 0.4711 - loss: -2.4664
# Epoch 14: val_loss improved from -0.33209 to -0.38963, saving model to unet_resnet101_best_model.keras
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 75s 351ms/step - f1-score: 0.5567 - iou_score: 0.4711 - loss: -2.4655 - val_f1-score: 0.7190 - val_iou_score: 0.6489 - val_loss: -0.3896 - learning_rate: 2.0000e-05
# Epoch 15/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - f1-score: 0.5770 - iou_score: 0.4949 - loss: -2.3746
# Epoch 15: val_loss did not improve from -0.38963
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 69s 321ms/step - f1-score: 0.5771 - iou_score: 0.4949 - loss: -2.3768 - val_f1-score: 0.7465 - val_iou_score: 0.6758 - val_loss: -0.3514 - learning_rate: 2.0000e-05
# Epoch 16/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - f1-score: 0.5682 - iou_score: 0.4882 - loss: -2.2946
# Epoch 16: val_loss did not improve from -0.38963
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 68s 320ms/step - f1-score: 0.5684 - iou_score: 0.4883 - loss: -2.2963 - val_f1-score: 0.6922 - val_iou_score: 0.6172 - val_loss: -0.0555 - learning_rate: 2.0000e-05
# Epoch 17/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - f1-score: 0.6163 - iou_score: 0.5381 - loss: -2.5006
# Epoch 17: val_loss did not improve from -0.38963
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 68s 320ms/step - f1-score: 0.6164 - iou_score: 0.5382 - loss: -2.5020 - val_f1-score: 0.7240 - val_iou_score: 0.6491 - val_loss: -0.3649 - learning_rate: 2.0000e-05
# Epoch 18/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - f1-score: 0.6252 - iou_score: 0.5495 - loss: -2.6363
# Epoch 18: val_loss did not improve from -0.38963
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 68s 320ms/step - f1-score: 0.6251 - iou_score: 0.5495 - loss: -2.6367 - val_f1-score: 0.6362 - val_iou_score: 0.5663 - val_loss: -0.0496 - learning_rate: 2.0000e-05
# Epoch 19/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - f1-score: 0.6492 - iou_score: 0.5714 - loss: -2.8232
# Epoch 19: val_loss did not improve from -0.38963
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 68s 320ms/step - f1-score: 0.6492 - iou_score: 0.5714 - loss: -2.8226 - val_f1-score: 0.7583 - val_iou_score: 0.6876 - val_loss: -0.3544 - learning_rate: 4.0000e-06
# Epoch 20/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - f1-score: 0.6898 - iou_score: 0.6153 - loss: -2.7606
# Epoch 20: val_loss did not improve from -0.38963
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 68s 320ms/step - f1-score: 0.6898 - iou_score: 0.6153 - loss: -2.7619 - val_f1-score: 0.7729 - val_iou_score: 0.7034 - val_loss: -0.3773 - learning_rate: 4.0000e-06
# Epoch 21/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - f1-score: 0.6836 - iou_score: 0.6101 - loss: -2.7217
# Epoch 21: val_loss did not improve from -0.38963
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 68s 321ms/step - f1-score: 0.6837 - iou_score: 0.6101 - loss: -2.7229 - val_f1-score: 0.7824 - val_iou_score: 0.7128 - val_loss: -0.3249 - learning_rate: 4.0000e-06
# Epoch 22/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - f1-score: 0.7044 - iou_score: 0.6329 - loss: -2.8965
# Epoch 22: val_loss did not improve from -0.38963
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1e-06.
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 68s 321ms/step - f1-score: 0.7044 - iou_score: 0.6329 - loss: -2.8966 - val_f1-score: 0.7717 - val_iou_score: 0.7021 - val_loss: -0.3589 - learning_rate: 4.0000e-06
# Epoch 23/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - f1-score: 0.7148 - iou_score: 0.6426 - loss: -2.7683
# Epoch 23: val_loss did not improve from -0.38963
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 68s 320ms/step - f1-score: 0.7147 - iou_score: 0.6426 - loss: -2.7698 - val_f1-score: 0.7696 - val_iou_score: 0.6993 - val_loss: -0.3435 - learning_rate: 1.0000e-06
# Epoch 24/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - f1-score: 0.6858 - iou_score: 0.6170 - loss: -2.0749
# Epoch 24: val_loss did not improve from -0.38963
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 68s 321ms/step - f1-score: 0.6859 - iou_score: 0.6170 - loss: -2.0786 - val_f1-score: 0.7742 - val_iou_score: 0.7035 - val_loss: -0.2100 - learning_rate: 1.0000e-06
#
# --- Model Training Complete ---
# Best model has been saved to: unet_resnet101_best_model.keras

# %% [markdown]
# ## Step 7: Visualize Training History
# Now that the training is complete, we can analyze the model's learning process. The history object we created contains the loss and metric values for both the training and validation sets at the end of each epoch.

# %%
import matplotlib.pyplot as plt

# --- Get the training history ---
history_dict = history.history

# --- Plot Loss ---
loss = history_dict['loss']
val_loss = history_dict['val_loss']
epochs = range(1, len(loss) + 1)

plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs, loss, 'b-', label='Training loss')
plt.plot(epochs, val_loss, 'r-', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

# --- Plot IoU Score ---
iou = history_dict['iou_score']
val_iou = history_dict['val_iou_score']

plt.subplot(1, 2, 2)
plt.plot(epochs, iou, 'b-', label='Training IoU Score')
plt.plot(epochs, val_iou, 'r-', label='Validation IoU Score')
plt.title('Training and Validation IoU Score')
plt.xlabel('Epochs')
plt.ylabel('IoU Score')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Step 8: Evaluate on the Test Set
# The ultimate test of a model is its performance on completely unseen data. We will now load the best weights we saved during training (from the .keras file) and evaluate the model's performance on the X_test and Y_test datasets.

# %%
from sklearn.metrics import classification_report

# --- Load the best saved model weights ---
# Note: Since we used restore_best_weights=True, the model in memory is already the best one.
# This is just to demonstrate how to load it from the file for future use.
unet_resnet101_model.load_weights(model_weights_path)
print(f"Loaded best model weights from {model_weights_path}")

# --- Evaluate the model on the test data ---
print("\n--- Evaluating model on the test set ---")
# --- CHANGE HERE: Use the preprocessed test data for evaluation ---
results = unet_resnet101_model.evaluate(X_test_preprocessed, Y_test_cat, batch_size=BATCH_SIZE)
print(f"Test Loss: {results[0]}")
print(f"Test IoU Score: {results[1]}")
print(f"Test F1-Score: {results[2]}")

# --- Generate Classification Report ---
# To do this, we need to get predictions for the test set
print("\n--- Generating Classification Report ---")
# --- CHANGE HERE: Use the preprocessed test data for prediction ---
y_pred = unet_resnet101_model.predict(X_test_preprocessed)
y_pred_argmax = np.argmax(y_pred, axis=3)

# We need to flatten the arrays to compare them
y_test_flat = Y_test.flatten()
y_pred_flat = y_pred_argmax.flatten()

# Define class names (assuming 0: background, 1-3: weed types)
class_names = ['Background', 'Weed Type 1', 'Weed Type 2', 'Weed Type 3']

print(classification_report(y_test_flat, y_pred_flat, target_names=class_names))
# Out:
# Loaded best model weights from unet_resnet101_best_model.keras
#
# --- Evaluating model on the test set ---
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 264ms/step - f1-score: 0.6877 - iou_score: 0.5917 - loss: -2.5210
# Test Loss: -1.62895667552948
# Test IoU Score: 0.5424179434776306
# Test F1-Score: 0.6391148567199707
#
# --- Generating Classification Report ---
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step
#               precision    recall  f1-score   support
#
#   Background       0.93      0.87      0.90   8360540
#  Weed Type 1       0.66      0.73      0.69    331575
#  Weed Type 2       0.32      0.43      0.37     84337
#  Weed Type 3       0.54      0.70      0.61   1578236
#
#     accuracy                           0.84  10354688
#    macro avg       0.61      0.68      0.64  10354688
# weighted avg       0.86      0.84      0.85  10354688

# %% [markdown]
# ## Step 9: Visual Inference on Test Images
# Finally, let's look at some actual predictions. We'll pick a few random images from our test set and compare the original image, the ground truth mask provided by the dataset, and the segmentation mask predicted by our trained model. This gives us a qualitative understanding of where the model is performing well and where it might be making mistakes.

# %%
import random

# --- Select a few random images from the test set ---
num_images_to_show = 3
test_indices = [random.randint(0, len(X_test) - 1) for _ in range(num_images_to_show)]

for i, index in enumerate(test_indices):
    # Get the ORIGINAL image for display purposes
    test_img = X_test[index]
    
    # Get the ground truth mask
    ground_truth = Y_test[index]
    
    # --- CHANGE HERE: Get the corresponding PREPROCESSED image for the model ---
    test_img_preprocessed = X_test_preprocessed[index]
    
    # Expand dims to add the batch dimension for prediction
    test_img_input = np.expand_dims(test_img_preprocessed, 0)
    
    # Make the prediction using the preprocessed image
    prediction = unet_resnet101_model.predict(test_img_input)
    predicted_img = np.argmax(prediction, axis=3)[0,:,:]

    plt.figure(figsize=(15, 6))
    plt.suptitle(f'Test Image #{index}', fontsize=16)
    
    plt.subplot(1, 3, 1)
    plt.title('Input Image')
    plt.imshow(test_img) # Display the original image
    plt.axis('off')
    
    plt.subplot(1, 3, 2)
    plt.title('Ground Truth Mask')
    plt.imshow(ground_truth, cmap='jet')
    plt.axis('off')

    plt.subplot(1, 3, 3)
    plt.title('Predicted Mask')
    plt.imshow(predicted_img, cmap='jet')
    plt.axis('off')
    
    plt.tight_layout()
    plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step

# %% [markdown]
# ## Step 10: Calculating Mean IoU and Mean Precision
# While Mean Average Precision (mAP) is the primary metric for object detection tasks, the direct and standard equivalent for semantic segmentation is Mean Intersection over Union (mIoU).

# %%
import tensorflow as tf
import numpy as np

# This cell requires the variables 'y_pred_argmax' and 'Y_test' 
# from the evaluation cell (Cell 19) to be available.

# --- 1. Calculate Mean IoU (mIoU) ---
print("--- Calculating Mean IoU (mIoU) and Class-wise IoU ---")

# Instantiate the Keras MeanIoU metric
# Use the 'n_classes' variable from our data preparation step
iou_metric = tf.keras.metrics.MeanIoU(num_classes=n_classes)

# Update the metric's state with the ground truth and predictions
# Note: We use Y_test (integer labels) and y_pred_argmax (integer labels), 
# NOT the one-hot encoded categorical versions.
iou_metric.update_state(Y_test, y_pred_argmax)

# Get the final Mean IoU result.
mean_iou = iou_metric.result().numpy()

print(f"\nMean Intersection over Union (mIoU): {mean_iou:.4f}")
print("This is the primary metric for evaluating a semantic segmentation model.")


# --- 2. Calculate and Display Class-wise IoU ---
print("\n--- IoU Scores for Each Class ---")
# ### FIX: Access the confusion matrix directly from the 'total_cm' variable ###
confusion_matrix = iou_metric.total_cm.numpy()

# Calculate IoU for each class
# The rest of this logic remains the same
for i in range(n_classes):
    # True Positives are on the diagonal
    true_positives = confusion_matrix[i, i]
    # False Positives are the sum of the column, excluding the diagonal
    false_positives = np.sum(confusion_matrix[:, i]) - true_positives
    # False Negatives are the sum of the row, excluding the diagonal
    false_negatives = np.sum(confusion_matrix[i, :]) - true_positives
    
    # Calculate IoU
    denominator = true_positives + false_positives + false_negatives
    iou = true_positives / (denominator + 1e-6) # Add epsilon to avoid division by zero
    
    # Use the class_names defined in Cell 19
    print(f"Class '{class_names[i]}': IoU = {iou:.4f}")

    
# --- 3. Extract Mean Precision from Classification Report ---
# This part was already correct and requires no changes.
report = classification_report(y_test_flat, y_pred_flat, output_dict=True)
mean_precision = report['macro avg']['precision']

print(f"\nMean Average Precision (Macro Avg): {mean_precision:.4f}")
print("This is the unweighted average of the precision scores for each class.")
# Out:
# --- Calculating Mean IoU (mIoU) and Class-wise IoU ---
#
# Mean Intersection over Union (mIoU): 0.5044
# This is the primary metric for evaluating a semantic segmentation model.
#
# --- IoU Scores for Each Class ---
# Class 'Background': IoU = 0.8212
# Class 'Weed Type 1': IoU = 0.5306
# Class 'Weed Type 2': IoU = 0.2255
# Class 'Weed Type 3': IoU = 0.4402
#
# Mean Average Precision (Macro Avg): 0.6139
# This is the unweighted average of the precision scores for each class.

# %%
from IPython.display import FileLink
FileLink('unet_resnet101_best_model.keras')
# Out:
# /kaggle/working/unet_resnet101_best_model.keras

# %%
# !ls -lh unet_resnet101_best_model.keras
# Out:
# -rw-r--r-- 1 root root 592M Aug 11 20:51 unet_resnet101_best_model.keras
